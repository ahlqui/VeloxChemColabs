# %% [markdown]
# <a href="https://colab.research.google.com/github/ahlqui/VeloxChemColabs/blob/main/OrbitalVisualizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Optimize geometry and visualize orbitals

# %% [markdown]
# This notebook requires that you have a molecular structure. Two options:
#
# Define Molecule as XYZ-coordinates: Can be generatred with free software such as www.avogadro.cc
#
# Define Molecule with SMILES code, A molecule can be defined using a SMILES code (example below). We have two suggested ways to generate smiles from structure. 1) Sketch your molecule at https://www.rcsb.org/chemical-sketch and the SMILES code will be shown right below the structure. 2) Build your molecule at https://molview.org/ , go to Tools/Information Card and it will show you the SMILES code. Just copy/paste it into the SMILES box below.
#
# Example of xyz-coordinates for CO2:
#
# O 0.00 0.00 0.00
#
# C 0.00 0.00 1.20
#
# O 0.00 0.00 2.40
#
# Example of SMILES for CO2:
#
# O=C=O

# %%
#@title Install VeloxChem and dependencies (ca 2 min)
#@markdown Before you can run anything a few things need to be installed. It all runs on the Google Colab server an you do not need to install anything on your computer.
# %%capture
import sys

! wget -qnc https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
! bash Miniforge3-Linux-x86_64.sh -bfp /usr/local
! mamba config --set auto_update_conda false
import sys
sys.path.append('/usr/local/lib/python3.11/site-packages/')
# !mamba install -y -c conda-forge -c veloxchem veloxchem  py3Dmol dftd4-python  matplotlib python=3.11
! pip install rdkit
import veloxchem as vlx

# %%
xyz_coordinates = """
N     0.4785967928750  -0.4330741880750  -0.4934317502006
H     1.3794564278886   0.0429751463168  -0.5120458348956
C     0.4573285404340  -1.3154740355836  -1.6452845209868
H     1.2794157350200  -2.0270971721773  -1.5868316520123
H    -0.4697908768414  -1.8882598290096  -1.6558792536570
C     0.3747047426388  -1.2102491878280   0.7331072010194
H    -0.4082292852521  -1.9567463178277   0.6148319854093
H     1.2952953868059  -1.7540437197433   0.9183116804327
C     0.6956425554192   0.9059967227241  -5.3588904651214
C     1.6690431285267  -0.0704102447688  -5.0614336089256
C     1.5905279342425  -0.7922292640998  -3.8527793116028
C     0.5421211238334  -0.5430166236398  -2.9451176135833
C    -0.4312572408155   0.4285446612223  -3.2497814984180
C    -0.3564249048118   1.1570067527526  -4.4544417171718
H     0.7549521548685   1.4652126122086  -6.2812972715425
H     2.3338053657174  -1.5390048087124  -3.6163728176857
H    -1.2215586002930   0.6165771400284  -2.5371827271696
C    -0.5809783149118   1.1061887532548   4.2819306994214
C    -1.0539691464599  -0.2152180430193   4.1484967454886
C    -0.7402866542775  -0.9585904738513   2.9917812697427
C     0.0501603450518  -0.3918335577218   1.9715484114033
C     0.5329231859523   0.9234697295847   2.1220017776407
C     0.2096151223583   1.6793509886579   3.2655299818144
H    -0.8298576406810   1.6816374807225   5.1614537759970
H    -1.1155297675244  -1.9639771384900   2.8737258346041
H     1.1311551788061   1.3586475153088   1.3389498331805
C     2.7985412681099  -0.3440921389086  -6.0320361103160
H     3.0137177612643  -1.4119025048439  -6.0784904425001
H     2.5433990952730  -0.0090827377477  -7.0376742707821
H     3.7013243404231   0.1769923076871  -5.7132670703364
C    -1.3956677617432   2.2110713683443  -4.7713360805252
H    -2.2850215726603   2.0829577471538  -4.1532353918110
H    -0.9892606342753   3.2051959925139  -4.5854917335667
H    -1.6989550492144   2.1496453780473  -5.8166145479409
C    -1.9096053739985  -0.8269385079269   5.2372774019485
H    -1.8730938416183  -1.9157634078951   5.1986764605346
H    -1.5629099527925  -0.5125717843390   6.2218512212214
H    -2.9465170241487  -0.5126306418706   5.1188520156529
C     0.7055071531436   3.1039291474455   3.3878074482962
H     0.6996321098764   3.5926125742168   2.4126899821207
H     0.0720511304863   3.6841458846608   4.0587668370105
H     1.7245462284362   3.1151446899290   3.7742478882927
"""

# %%
#@title Define your molecule, either asa SMILES code or xyz-coordinates above
#@markdown - Enter the SMILES code
smiles_code = 'OCCC=O' #@param {type:"string"}
#@markdown - If you want to use the xyz coordinates in the previous cell check box
use_xyz = False # @param {type:"boolean"}
if use_xyz == False:
  molecule = vlx.Molecule.read_smiles(smiles_code)
else:
  molecule = vlx.Molecule.read_str(xyz_coordinates)
print('Structure of the molecule entered: ')
molecule.show(atom_indices=True)
# Out:
# Structure of the molecule entered:
# <div id="3dmolviewer_17473255153047388"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17473255153047388" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17473255153047388 = null;
# var warn = document.getElementById("3dmolwarning_17473255153047388");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17473255153047388 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17473255153047388"),{backgroundColor:"white"});
# viewer_17473255153047388.zoomTo();
# 	viewer_17473255153047388.addModel("11\n\nO              0.404413000000         1.986409000000         0.584596000000\nC             -0.446827000000         0.920760000000         0.911528000000\nC              0.323179000000        -0.201096000000         1.614992000000\nC              1.331688000000        -0.836189000000         0.703564000000\nO              2.308835000000        -0.209331000000         0.325983000000\nH              0.592465000000         2.469765000000         1.431215000000\nH             -1.270168000000         1.277560000000         1.571159000000\nH             -0.910200000000         0.529921000000        -0.019752000000\nH              0.833849000000         0.194457000000         2.519367000000\nH             -0.400221000000        -0.978099000000         1.943006000000\nH              1.203968000000        -1.867256000000         0.390219000000\n");
# 	viewer_17473255153047388.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17473255153047388.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17473255153047388.addLabel("1",{"position": {"x": 0.40441299999999997, "y": 1.986409, "z": 0.584596}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("2",{"position": {"x": -0.446827, "y": 0.92076, "z": 0.911528}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("3",{"position": {"x": 0.323179, "y": -0.201096, "z": 1.614992}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("4",{"position": {"x": 1.331688, "y": -0.836189, "z": 0.703564}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("5",{"position": {"x": 2.3088349999999997, "y": -0.209331, "z": 0.325983}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("6",{"position": {"x": 0.592465, "y": 2.469765, "z": 1.431215}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("7",{"position": {"x": -1.270168, "y": 1.27756, "z": 1.571159}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("8",{"position": {"x": -0.9102, "y": 0.529921, "z": -0.019751999999999995}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("9",{"position": {"x": 0.8338489999999998, "y": 0.194457, "z": 2.5193669999999995}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("10",{"position": {"x": -0.400221, "y": -0.9780989999999999, "z": 1.943006}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.addLabel("11",{"position": {"x": 1.2039679999999997, "y": -1.867256, "z": 0.390219}, "alignment": "center", "fontColor": 0, "backgroundColor": 16777215, "backgroundOpacity": 0.0});
# 	viewer_17473255153047388.zoomTo();
# viewer_17473255153047388.render();
# });
# </script>

# %%
#@title DFT single point and generation of orbital data
#@markdown Example timing: ibuprofen PBE/DEF2-SVP (8 min)
basis_set = 'DEF2-SVP' #@param  ['6-31++G', '6-31++G*', '6-31++G**', '6-31+G', '6-31+G*', '6-31+G**', '6-311++G', '6-311++G(2D,2P)', '6-311++G(3DF,3PD)', '6-311++G*', '6-311++G**', '6-311+G', '6-311+G(2D,P)', '6-311+G*', '6-311+G**', '6-311G', '6-311G(2DF,2PD)', '6-311G*', '6-311G**', '6-31G', '6-31G(2DF,P)', '6-31G(3DF,3PD)', '6-31G*', '6-31G**', 'ANO-L-MB', 'ANO-L-VDZP', 'ANO-L-VQZP', 'ANO-L-VTZP', 'ANO-S-MB', 'ANO-S-VDZP', 'AO-START-GUESS', 'AUG-CC-PCV5Z', 'AUG-CC-PCVDZ', 'AUG-CC-PCVQZ', 'AUG-CC-PCVTZ', 'AUG-CC-PV5Z', 'AUG-CC-PV6Z', 'AUG-CC-PVDZ', 'AUG-CC-PVQZ', 'AUG-CC-PVTZ', 'AUG-PCSEG-0', 'AUG-PCSEG-1', 'AUG-PCSEG-2', 'AUG-PCSEG-3', 'AUG-PCSEG-4', 'AUG-PCX-1', 'AUG-PCX-2', 'AUG-PCX-3', 'AUG-PCX-4', 'CC-PCV5Z', 'CC-PCVDZ', 'CC-PCVQZ', 'CC-PCVTZ', 'CC-PV5Z', 'CC-PV6Z', 'CC-PVDZ', 'CC-PVQZ', 'CC-PVTZ', 'DAUG-CC-PCV5Z', 'DAUG-CC-PCVDZ', 'DAUG-CC-PCVQZ', 'DAUG-CC-PCVTZ', 'DAUG-CC-PV5Z', 'DAUG-CC-PV6Z', 'DAUG-CC-PVDZ', 'DAUG-CC-PVQZ', 'DAUG-CC-PVTZ', 'DEF2-QZVP', 'DEF2-QZVPD', 'DEF2-QZVPP', 'DEF2-QZVPPD', 'DEF2-SV(P)', 'DEF2-SVP', 'DEF2-SVPD', 'DEF2-TZVP', 'DEF2-TZVPD', 'DEF2-TZVPP', 'DEF2-TZVPPD', 'PCSEG-0', 'PCSEG-1', 'PCSEG-2', 'PCSEG-3', 'PCSEG-4', 'PCX-1', 'PCX-2', 'PCX-3', 'PCX-4', 'SADLEJ-PVTZ', 'STO-3G', 'STO-3G-OLD', 'STO-6G', 'TAUG-CC-PCV5Z', 'TAUG-CC-PCVDZ', 'TAUG-CC-PCVQZ', 'TAUG-CC-PCVTZ', 'TAUG-CC-PV5Z', 'TAUG-CC-PV6Z', 'TAUG-CC-PVDZ', 'TAUG-CC-PVQZ', 'TAUG-CC-PVTZ']
basis = vlx.MolecularBasis.read(molecule, basis_set)
vis_drv = vlx.VisualizationDriver()
scf_drv = vlx.ScfRestrictedDriver()
scf_drv.conv_thresh = 1e-3
scf_drv.grid_level = 2
scf_drv.update_settings(method_dict)
mute_output = True # @param {type:"boolean"}
if mute_output == True:
  scf_drv.ostream.mute()
else:
  scf_drv.ostream
functional = 'PBE' #@param ['SLATER', 'SLDA', 'B88X', 'BLYP', 'B3LYP', 'BHANDH', 'BHANDHLYP', 'PBE', 'PBE0', 'REVPBE', 'BP86', 'PW91', 'MPW1K', 'OLYP', 'O3LYP', 'X3LYP', 'B97', 'B97-1', 'B97-2', 'B97-3', 'TPSS', 'TPSSH', 'REVTPSS', 'PKZB', 'SCAN', 'RSCAN', 'R2SCAN', 'M05', 'M05-2X', 'M06', 'M06-2X', 'M06-HF', 'M06-L', 'M11-L', 'MPW1B95', 'MPWB1K', 'PW6B95', 'PWB6K']
scf_drv.xcfun = functional
use_RI = True # @param {type:"boolean"}
if use_RI == True:
  scf_drv.ri_coulomb = True
else:
  scf_drv.ri_coulomb = False
scf_drv.compute(molecule, basis)
scf_results = scf_drv.compute(molecule, basis)
vis_drv.gen_cubes(
    cube_dict={
        "grid": "30,30,30",
        "cubes": "mo(homo),mo(lumo),mo(homo-1),mo(homo-2),mo(homo-3),mo(homo-4),mo(lumo+1),mo(lumo+2)",
        "files": "HOMO.cube, LUMO.cube, HOMO-1.cube, HOMO-2.cube, HOMO-3.cube, HOMO-4.cube, LUMO+1.cube, LUMO+2.cube",
    },
    molecule=molecule,
    basis=basis,
    mol_orbs=scf_drv.mol_orbs,
    density=scf_drv.density,
)
print(f"DFT energy: {scf_drv.get_scf_energy():14.10f} a.u.")
# Out:
# DFT energy: -267.8280188734 a.u.

# %%
#@title Visualize the MOs
import py3Dmol
viewer = py3Dmol.view(linked=False, width=500, height=500)
orbital = 'LUMO' #@param ['HOMO-4', 'HOMO-3', 'HOMO-2', 'HOMO-1', 'HOMO', 'LUMO', 'LUMO+1', 'LUMO+2']

# HOMO
with open(orbital + ".cube", "r") as f:
    cube = f.read()
# Plot stick structures
viewer.addModel(molecule.get_xyz_string(), "xyz")
viewer.setStyle({"stick": {}})
# Negative and positive nodes
viewer.addVolumetricData(
    cube, "cube", {"isoval": -0.02, "color": "blue", "opacity": 0.75}
)
viewer.addVolumetricData(
    cube, "cube", {"isoval": 0.02, "color": "red", "opacity": 0.75}
)
viewer.rotate(-45, "x")

viewer.zoomTo()
viewer.show()
# Out:
# <div id="3dmolviewer_17473262500967834"  style="position: relative; width: 500px; height: 500px;">
#         <p id="3dmolwarning_17473262500967834" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17473262500967834 = null;
# var warn = document.getElementById("3dmolwarning_17473262500967834");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17473262500967834 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17473262500967834"),{backgroundColor:"white"});
# viewer_17473262500967834.zoomTo();
# 	viewer_17473262500967834.addModel("11\n\nO              0.404413000000         1.986409000000         0.584596000000\nC             -0.446827000000         0.920760000000         0.911528000000\nC              0.323179000000        -0.201096000000         1.614992000000\nC              1.331688000000        -0.836189000000         0.703564000000\nO              2.308835000000        -0.209331000000         0.325983000000\nH              0.592465000000         2.469765000000         1.431215000000\nH             -1.270168000000         1.277560000000         1.571159000000\nH             -0.910200000000         0.529921000000        -0.019752000000\nH              0.833849000000         0.194457000000         2.519367000000\nH             -0.400221000000        -0.978099000000         1.943006000000\nH              1.203968000000        -1.867256000000         0.390219000000\n","xyz");
# 	viewer_17473262500967834.setStyle({"stick": {}});
# 	viewer_17473262500967834.addVolumetricData("Cube file generated by VeloxChem\nMO 21 (alpha)\n  -11   -7.269449   -8.005237   -5.128749    1\n   30    0.579243    0.000000    0.000000\n   30    0.000000    0.583459    0.000000\n   30    0.000000    0.000000    0.486857\n    8    8.000000    0.764230    3.753769    1.104726\n    6    6.000000   -0.844381    1.739984    1.722538\n    6    6.000000    0.610720   -0.380016    3.051893\n    6    6.000000    2.516526   -1.580168    1.329543\n    8    8.000000    4.363066   -0.395578    0.616019\n    1    1.000000    1.119597    4.667179    2.704604\n    1    1.000000   -2.400270    2.414239    2.969060\n    1    1.000000   -1.720029    1.001406   -0.037326\n    1    1.000000    1.575746    0.367470    4.760914\n    1    1.000000   -0.756308   -1.848339    3.671749\n    1    1.000000    2.275170   -3.528602    0.737407\n    1   21\n -1.21912E-09 -2.19116E-09 -3.74351E-09 -6.10162E-09 -9.53650E-09 -1.43887E-08\n -2.11268E-08 -3.04401E-08 -4.33362E-08 -6.11674E-08 -8.54892E-08 -1.17668E-07\n -1.58246E-07 -2.06211E-07 -2.58461E-07 -3.09778E-07 -3.53526E-07 -3.83011E-07\n -3.93141E-07 -3.81815E-07 -3.50553E-07 -3.04095E-07 -2.49152E-07 -1.92762E-07\n -1.40806E-07 -9.71008E-08 -6.32124E-08 -3.88460E-08 -2.25344E-08 -1.23395E-08\n\n -4.23805E-09 -7.59149E-09 -1.28960E-08 -2.08287E-08 -3.21039E-08 -4.74659E-08\n -6.77737E-08 -9.42041E-08 -1.28523E-07 -1.73251E-07 -2.31476E-07 -3.06075E-07\n -3.98311E-07 -5.06140E-07 -6.22876E-07 -7.37009E-07 -8.33697E-07 -8.97833E-07\n -9.17847E-07 -8.88955E-07 -8.14632E-07 -7.05749E-07 -5.77710E-07 -4.46672E-07\n -3.26131E-07 -2.24833E-07 -1.46336E-07 -8.99176E-08 -5.21585E-08 -2.85619E-08\n\n -1.35006E-08 -2.41228E-08 -4.08110E-08 -6.54899E-08 -9.99463E-08 -1.45618E-07\n -2.03620E-07 -2.75149E-07 -3.62210E-07 -4.68312E-07 -5.98497E-07 -7.58066E-07\n -9.49807E-07 -1.17031E-06 -1.40684E-06 -1.63653E-06 -1.82923E-06 -1.95376E-06\n -1.98605E-06 -1.91608E-06 -1.75115E-06 -1.51422E-06 -1.23782E-06 -9.56113E-07\n -6.97589E-07 -4.80660E-07 -3.12728E-07 -1.92110E-07 -1.11421E-07 -6.10107E-08\n\n -3.95053E-08 -7.04570E-08 -1.18848E-07 -1.89840E-07 -2.87687E-07 -4.14760E-07\n -5.71156E-07 -7.55426E-07 -9.66466E-07 -1.20587E-06 -1.47925E-06 -1.79480E-06\n -2.15842E-06 -2.56621E-06 -2.99742E-06 -3.41173E-06 -3.75374E-06 -3.96489E-06\n -3.99921E-06 -3.83741E-06 -3.49368E-06 -3.01265E-06 -2.45774E-06 -1.89551E-06\n -1.38137E-06 -9.50956E-07 -6.18289E-07 -3.79623E-07 -2.20096E-07 -1.20490E-07\n\n -1.06307E-07 -1.89334E-07 -3.18685E-07 -5.07368E-07 -7.65031E-07 -1.09470E-06\n -1.49092E-06 -1.94097E-06 -2.42953E-06 -2.94563E-06 -3.48836E-06 -4.06721E-06\n -4.69433E-06 -5.37024E-06 -6.06843E-06 -6.72731E-06 -7.25580E-06 -7.55369E-06\n -7.54053E-06 -7.18208E-06 -6.50383E-06 -5.58618E-06 -4.54357E-06 -3.49598E-06\n -2.54298E-06 -1.74799E-06 -1.13511E-06 -6.96258E-07 -4.03361E-07 -2.20690E-07\n\n -2.63203E-07 -4.68276E-07 -7.86944E-07 -1.24987E-06 -1.87786E-06 -2.67273E-06\n -3.61156E-06 -4.64833E-06 -5.72512E-06 -6.79038E-06 -7.81655E-06 -8.80744E-06\n -9.78804E-06 -1.07779E-05 -1.17591E-05 -1.26545E-05 -1.33316E-05 -1.36345E-05\n -1.34332E-05 -1.26716E-05 -1.13926E-05 -9.73137E-06 -7.88077E-06 -6.04235E-06\n -4.38231E-06 -3.00481E-06 -1.94713E-06 -1.19219E-06 -6.89623E-07 -3.76844E-07\n\n -5.99705E-07 -1.06609E-06 -1.78943E-06 -2.83709E-06 -4.25155E-06 -6.02821E-06\n -8.10045E-06 -1.03419E-05 -1.25913E-05 -1.46960E-05 -1.65576E-05 -1.81577E-05\n -1.95474E-05 -2.07993E-05 -2.19420E-05 -2.29090E-05 -2.35330E-05 -2.35913E-05\n -2.28885E-05 -2.13384E-05 -1.90101E-05 -1.61201E-05 -1.29761E-05 -9.89820E-06\n -7.14682E-06 -4.88102E-06 -3.15182E-06 -1.92378E-06 -1.10975E-06 -6.04977E-07\n\n -1.25759E-06 -2.23416E-06 -3.74661E-06 -5.93239E-06 -8.87345E-06 -1.25478E-05\n -1.67960E-05 -2.13244E-05 -2.57573E-05 -2.97304E-05 -3.29933E-05 -3.54759E-05\n -3.72809E-05 -3.85985E-05 -3.95780E-05 -4.02193E-05 -4.03412E-05 -3.96458E-05\n -3.78524E-05 -3.48362E-05 -3.07086E-05 -2.58088E-05 -2.06 ...
